# %% [markdown]
# Data Manipulation using Pandas library functions:
#
# head()  info()  tail()  shape() isnull()  to_string()  loc[] iloc[]
#
#
# info() columns  nlargest() nsmallest()  astype() where()
#
#
# value_counts() groupby() unique()  cut() qcut()  merge()
#
#
# dtype() squeeze()  isnull().sum()  series()  T.iloc()
#
#
# isin([])  sample() nsample()   corrwith() cov()

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/Hricha/Downloads/wine.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
df.shape
# Out:
# (178, 14)

# %%
df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
df.dropna()
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
# ..    ...      ...         ...   ...   ...    ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95.0     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102.0     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120.0     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120.0     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96.0     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# ...

# %%
print(df.to_string())
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  Nonflavanoid.phenols  Proanth  Color.int    Hue    OD  Proline
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06                  0.28     2.29   5.640000  1.040  3.92     1065
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76                  0.26     1.28   4.380000  1.050  3.40     1050
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24                  0.30     2.81   5.680000  1.030  3.17     1185
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49                  0.24     2.18   7.800000  0.860  3.45     1480
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69                  0.39     1.82   4.320000  1.040  2.93      735
# 5       1    14.20        1.76  2.45  15.2  112     3.27        3.39                  0.34     1.97   6.750000  1.050  2.85     1450
# ...

# %%
"""Locate ROWS """
print(df.loc[0])
# Out:
# Wine                       1.00
# Alcohol                   14.23
# Malic.acid                 1.71
# Ash                        2.43
# Acl                       15.60
# Mg                       127.00
# Phenols                    2.80
# Flavanoids                 3.06
# Nonflavanoid.phenols       0.28
# Proanth                    2.29
# Color.int                  5.64
# Hue                        1.04
# OD                         3.92
# Proline                 1065.00
# Name: 0, dtype: float64

# %%
print(df.loc[[0,1]])
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050

# %%
df["Wine"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
df[["Wine","Alcohol","Malic.acid"]]
# Out:
#      Wine  Alcohol  Malic.acid
# 0       1    14.23        1.71
# 1       1    13.20        1.78
# 2       1    13.16        2.36
# 3       1    14.37        1.95
# 4       1    13.24        2.59
# ..    ...      ...         ...
# 173     3    13.71        5.65
# 174     3    13.40        3.91
# 175     3    13.27        4.28
# 176     3    13.17        2.59
# 177     3    14.13        4.10
#
# [178 rows x 3 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# ...

# %%
df.columns
# Out:
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue',
#        'OD', 'Proline'],
#       dtype='object')

# %%
df.sort_values('Alcohol')
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 115     2    11.03        1.51  2.20  21.5   85     2.46        2.17
# 113     2    11.41        0.74  2.50  21.0   88     2.48        2.01
# 120     2    11.45        2.40  2.42  20.0   96     2.90        2.79
# 110     2    11.46        3.74  1.82  19.5  107     3.18        2.58
# 121     2    11.56        2.05  3.23  28.5  119     3.18        5.08
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 46      1    14.38        3.59  2.28  16.0  102     3.25        3.17
# 14      1    14.38        1.87  2.38  12.0  102     3.30        3.64
# 6       1    14.39        1.87  2.45  14.6   96     2.50        2.52
# 13      1    14.75        1.73  2.39  11.4   91     3.10        3.69
# 8       1    14.83        1.64  2.17  14.0   97     2.80        2.98
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 115                  0.52     2.01       1.90  1.71  2.87      407
# ...

# %%
df.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %%
df.sample()
# Out:
#      Wine  Alcohol  Malic.acid  Ash   Acl  Mg  Phenols  Flavanoids  \
# 164     3    13.78        2.76  2.3  22.0  90     1.35        0.68
#
#      Nonflavanoid.phenols  Proanth  Color.int  Hue    OD  Proline
# 164                  0.41     1.03       9.58  0.7  1.68      615

# %%
df.sample(10)
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 172     3    14.16        2.51  2.48  20.0   91     1.68        0.70
# 86      2    12.16        1.61  2.31  22.8   90     1.78        1.69
# 16      1    14.30        1.92  2.72  20.0  120     2.80        3.14
# 150     3    13.50        3.12  2.62  24.0  123     1.40        1.57
# 8       1    14.83        1.64  2.17  14.0   97     2.80        2.98
# 38      1    13.07        1.50  2.10  15.5   98     2.40        2.64
# 112     2    11.76        2.68  2.92  20.0  103     1.75        2.03
# 162     3    12.85        3.27  2.58  22.0  106     1.65        0.60
# 132     3    12.81        2.31  2.40  24.0   98     1.15        1.09
# 51      1    13.83        1.65  2.60  17.2   94     2.45        2.99
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 172                  0.44     1.24       9.70  0.62  1.71      660
# 86                   0.43     1.56       2.45  1.33  2.26      495
# ...

# %%
df.nsmallest(10,"Mg")
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl  Mg  Phenols  Flavanoids  \
# 89      2    12.08        1.33  2.30  23.6  70     2.20        1.59
# 66      2    13.11        1.01  1.70  15.0  78     2.98        3.18
# 67      2    12.37        1.17  1.92  19.6  78     2.11        2.00
# 82      2    12.08        1.13  2.51  24.0  78     2.00        1.58
# 92      2    12.69        1.53  2.26  20.7  80     1.38        1.46
# 106     2    12.25        1.73  2.12  19.0  80     1.65        2.03
# 118     2    12.77        3.43  1.98  16.0  80     1.63        1.25
# 129     2    12.04        4.30  2.38  22.0  80     2.10        1.75
# 146     3    13.88        5.04  2.23  20.0  80     0.98        0.34
# 90      2    12.08        1.83  2.32  18.5  81     1.60        1.50
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 89                   0.42     1.38       1.74  1.07  3.21      625
# 66                   0.26     2.28       5.30  1.12  3.18      502
# ...

# %%
df.nlargest(10,"Mg")
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 95     2    12.47        1.52  2.20  19.0  162     2.50        2.27
# 69     2    12.21        1.19  1.75  16.8  151     1.85        1.28
# 73     2    12.99        1.67  2.60  30.0  139     3.30        2.89
# 78     2    12.33        0.99  1.95  14.8  136     1.90        1.85
# 96     2    11.81        2.12  2.74  21.5  134     1.60        0.99
# 33     1    13.76        1.53  2.70  19.5  132     2.95        2.74
# 39     1    14.22        3.99  2.51  13.2  128     3.00        3.04
# 0      1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 20     1    14.06        1.63  2.28  16.0  126     3.00        3.17
# 25     1    13.05        2.05  3.22  25.0  124     2.63        2.68
#
#     Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 95                  0.32     3.28       2.60  1.16  2.63      937
# 69                  0.14     2.50       2.85  1.28  3.07      718
# ...

# %%
df1=df.iloc[:,0:5].copy()

# %%
df1
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl
# 0       1    14.23        1.71  2.43  15.6
# 1       1    13.20        1.78  2.14  11.2
# 2       1    13.16        2.36  2.67  18.6
# 3       1    14.37        1.95  2.50  16.8
# 4       1    13.24        2.59  2.87  21.0
# ..    ...      ...         ...   ...   ...
# 173     3    13.71        5.65  2.45  20.5
# 174     3    13.40        3.91  2.48  23.0
# 175     3    13.27        4.28  2.26  20.0
# 176     3    13.17        2.59  2.37  20.0
# 177     3    14.13        4.10  2.74  24.5
#
# [178 rows x 5 columns]

# %%
df2=df.iloc[:,5:10].copy()

# %%
df2
# Out:
#       Mg  Phenols  Flavanoids  Nonflavanoid.phenols  Proanth
# 0    127     2.80        3.06                  0.28     2.29
# 1    100     2.65        2.76                  0.26     1.28
# 2    101     2.80        3.24                  0.30     2.81
# 3    113     3.85        3.49                  0.24     2.18
# 4    118     2.80        2.69                  0.39     1.82
# ..   ...      ...         ...                   ...      ...
# 173   95     1.68        0.61                  0.52     1.06
# 174  102     1.80        0.75                  0.43     1.41
# 175  120     1.59        0.69                  0.43     1.35
# 176  120     1.65        0.68                  0.53     1.46
# 177   96     2.05        0.76                  0.56     1.35
#
# [178 rows x 5 columns]

# %%
condition=df["Wine"]=='1'
df.where(condition,'condition_False')
# Out:
#                 Wine          Alcohol       Malic.acid              Ash  \
# 0    condition_False  condition_False  condition_False  condition_False
# 1    condition_False  condition_False  condition_False  condition_False
# 2    condition_False  condition_False  condition_False  condition_False
# 3    condition_False  condition_False  condition_False  condition_False
# 4    condition_False  condition_False  condition_False  condition_False
# ..               ...              ...              ...              ...
# 173  condition_False  condition_False  condition_False  condition_False
# 174  condition_False  condition_False  condition_False  condition_False
# 175  condition_False  condition_False  condition_False  condition_False
# 176  condition_False  condition_False  condition_False  condition_False
# 177  condition_False  condition_False  condition_False  condition_False
#
#                  Acl               Mg          Phenols       Flavanoids  \
# ...

# %%
df[df["Acl"]>20]
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# 25      1    13.05        2.05  3.22  25.0  124     2.63        2.68
# 30      1    13.73        1.50  2.70  22.5  101     3.00        3.25
# 35      1    13.48        1.81  2.41  20.5  100     2.70        2.98
# 55      1    13.56        1.73  2.46  20.5  116     2.96        2.78
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 168     3    13.58        2.58  2.69  24.5  105     1.55        0.84
# 169     3    13.40        4.60  2.86  25.0  112     1.98        0.96
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ...

# %%
df["Mg"]=df["Mg"].astype("float")

# %%
df
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
# ..    ...      ...         ...   ...   ...    ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95.0     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102.0     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120.0     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120.0     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96.0     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# ...

# %%
df.columns.str.upper()
# Out:
# Index(['WINE', 'ALCOHOL', 'MALIC.ACID', 'ASH', 'ACL', 'MG', 'PHENOLS',
#        'FLAVANOIDS', 'NONFLAVANOID.PHENOLS', 'PROANTH', 'COLOR.INT', 'HUE',
#        'OD', 'PROLINE'],
#       dtype='object')

# %%
df["Mg"].value_counts()
# Out:
# 88.0     13
# 86.0     11
# 98.0      9
# 101.0     9
# 96.0      8
# 102.0     7
# 94.0      6
# 85.0      6
# 112.0     6
# 97.0      5
# 92.0      5
# 80.0      5
# 103.0     5
# 89.0      5
# 90.0      4
# 108.0     4
# 107.0     4
# 106.0     4
# 87.0      3
# 120.0     3
# 95.0      3
# 78.0      3
# 111.0     3
# 84.0      3
# 118.0     3
# 104.0     3
# 100.0     3
# 110.0     3
# 116.0     3
# 93.0      2
# 115.0     2
# 91.0      2
# 105.0     2
# 113.0     2
# 162.0     1
# 134.0     1
# 119.0     1
# 82.0      1
# 122.0     1
# 81.0      1
# 70.0      1
# 127.0     1
# 132.0     1
# 99.0      1
# 136.0     1
# 139.0     1
# 151.0     1
# 117.0     1
# 128.0     1
# 124.0     1
# 126.0     1
# 121.0     1
# 123.0     1
# Name: Mg, dtype: int64

# %%
df["Mg"].value_counts().sum()
# Out:
# 178

# %%
df.iloc[:,0]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 173    3
# 174    3
# 175    3
# 176    3
# 177    3
# Name: Wine, Length: 178, dtype: int64

# %%
Alc=df.iloc[:,1]

# %%
Alc                                              #series of Alc
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: Alcohol, Length: 178, dtype: float64

# %%
Alc.dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 Alc.dtype()
#
# TypeError: 'numpy.dtype[float64]' object is not callable

# %%
serAlcohol = pd.Series(df['Alcohol'], index=df.index)

# %%
serAlcohol
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: Alcohol, Length: 178, dtype: float64

# %%
1/df
# Out:
#          Wine   Alcohol  Malic.acid       Ash       Acl        Mg   Phenols  \
# 0    1.000000  0.070274    0.584795  0.411523  0.064103  0.007874  0.357143
# 1    1.000000  0.075758    0.561798  0.467290  0.089286  0.010000  0.377358
# 2    1.000000  0.075988    0.423729  0.374532  0.053763  0.009901  0.357143
# 3    1.000000  0.069589    0.512821  0.400000  0.059524  0.008850  0.259740
# 4    1.000000  0.075529    0.386100  0.348432  0.047619  0.008475  0.357143
# ..        ...       ...         ...       ...       ...       ...       ...
# 173  0.333333  0.072939    0.176991  0.408163  0.048780  0.010526  0.595238
# 174  0.333333  0.074627    0.255754  0.403226  0.043478  0.009804  0.555556
# 175  0.333333  0.075358    0.233645  0.442478  0.050000  0.008333  0.628931
# 176  0.333333  0.075930    0.386100  0.421941  0.050000  0.008333  0.606061
# 177  0.333333  0.070771    0.243902  0.364964  0.040816  0.010417  0.487805
#
# ...

# %% [markdown]
# # SORTING AND RANKING

# %%
df["Alcohol"].sort_values(ascending=False)
# Out:
# 8      14.83
# 13     14.75
# 6      14.39
# 46     14.38
# 14     14.38
#        ...
# 121    11.56
# 110    11.46
# 120    11.45
# 113    11.41
# 115    11.03
# Name: Alcohol, Length: 178, dtype: float64

# %%
df["Wine"].sort_values(ascending=False)
# Out:
# 177    3
# 153    3
# 151    3
# 150    3
# 149    3
#       ..
# 35     1
# 34     1
# 33     1
# 32     1
# 0      1
# Name: Wine, Length: 178, dtype: int64

# %% [raw]
# df.sort_values(["Alcohol","Wine"])

# %% [markdown]
# # Summarizing and Computing Descriptive statistics

# %%
df.sum()                         #sum of columns
# Out:
# Wine                       345.000000
# Alcohol                   2314.110000
# Malic.acid                 415.870000
# Ash                        421.240000
# Acl                       3470.100000
# Mg                       17754.000000
# Phenols                    408.530000
# Flavanoids                 361.210000
# Nonflavanoid.phenols        64.410000
# Proanth                    283.180000
# Color.int                  900.339999
# Hue                        170.426000
# OD                         464.880000
# Proline                 132947.000000
# dtype: float64

# %%
df.sum(axis=1)                     #sum of rows
# Out:
# 0      1246.00
# 1      1195.10
# 2      1342.82
# 3      1651.49
# 4       909.69
#         ...
# 173     894.26
# 174     911.74
# 175    1014.22
# 176    1016.97
# 177     720.60
# Length: 178, dtype: float64

# %%
df.sum(axis="columns")
# Out:
# 0      1246.00
# 1      1195.10
# 2      1342.82
# 3      1651.49
# 4       909.69
#         ...
# 173     894.26
# 174     911.74
# 175    1014.22
# 176    1016.97
# 177     720.60
# Length: 178, dtype: float64

# %%
df.mean()
# Out:
# Wine                      1.938202
# Alcohol                  13.000618
# Malic.acid                2.336348
# Ash                       2.366517
# Acl                      19.494944
# Mg                       99.741573
# Phenols                   2.295112
# Flavanoids                2.029270
# Nonflavanoid.phenols      0.361854
# Proanth                   1.590899
# Color.int                 5.058090
# Hue                       0.957449
# OD                        2.611685
# Proline                 746.893258
# dtype: float64

# %%
df.mean(axis="columns")
# Out:
# 0       89.000000
# 1       85.364286
# 2       95.915714
# 3      117.963571
# 4       64.977857
#           ...
# 173     63.875714
# 174     65.124286
# 175     72.444286
# 176     72.640714
# 177     51.471429
# Length: 178, dtype: float64

# %%
df.idxmax()
# Out:
# Wine                    130
# Alcohol                   8
# Malic.acid              123
# Ash                     121
# Acl                      73
# Mg                       95
# Phenols                  52
# Flavanoids              121
# Nonflavanoid.phenols    105
# Proanth                 110
# Color.int               158
# Hue                     115
# OD                       22
# Proline                  18
# dtype: int64

# %%
df.idxmin()
# Out:
# Wine                      0
# Alcohol                 115
# Malic.acid              113
# Ash                      59
# Acl                      59
# Mg                       89
# Phenols                 146
# Flavanoids              146
# Nonflavanoid.phenols     74
# Proanth                  60
# Color.int               119
# Hue                     151
# OD                      136
# Proline                  80
# dtype: int64

# %%
df.idxmin(axis="columns")
# Out:
# 0      Nonflavanoid.phenols
# 1      Nonflavanoid.phenols
# 2      Nonflavanoid.phenols
# 3      Nonflavanoid.phenols
# 4      Nonflavanoid.phenols
#                ...
# 173    Nonflavanoid.phenols
# 174    Nonflavanoid.phenols
# 175    Nonflavanoid.phenols
# 176    Nonflavanoid.phenols
# 177    Nonflavanoid.phenols
# Length: 178, dtype: object

# %%
df.idxmax(axis="columns")
# Out:
# 0      Proline
# 1      Proline
# 2      Proline
# 3      Proline
# 4      Proline
#         ...
# 173    Proline
# 174    Proline
# 175    Proline
# 176    Proline
# 177    Proline
# Length: 178, dtype: object

# %%
df.cumsum()
# Out:
#      Wine  Alcohol  Malic.acid     Ash     Acl       Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71    2.43    15.6    127.0     2.80        3.06
# 1       2    27.43        3.49    4.57    26.8    227.0     5.45        5.82
# 2       3    40.59        5.85    7.24    45.4    328.0     8.25        9.06
# 3       4    54.96        7.80    9.74    62.2    441.0    12.10       12.55
# 4       5    68.20       10.39   12.61    83.2    559.0    14.90       15.24
# ..    ...      ...         ...     ...     ...      ...      ...         ...
# 173   333  2260.14      400.99  411.39  3382.6  17316.0   401.44      358.33
# 174   336  2273.54      404.90  413.87  3405.6  17418.0   403.24      359.08
# 175   339  2286.81      409.18  416.13  3425.6  17538.0   404.83      359.77
# 176   342  2299.98      411.77  418.50  3445.6  17658.0   406.48      360.45
# 177   345  2314.11      415.87  421.24  3470.1  17754.0   408.53      361.21
#
# ...

# %%
df.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %%
df.columns
# Out:
# Index(['Wine', 'Alcohol', 'Malic.acid', 'Ash', 'Acl', 'Mg', 'Phenols',
#        'Flavanoids', 'Nonflavanoid.phenols', 'Proanth', 'Color.int', 'Hue',
#        'OD', 'Proline'],
#       dtype='object')

# %%
df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
df["Alcohol"].corr(df["Acl"])
# Out:
# -0.3102351368910852

# %%
df.corr()
# Out:
#                           Wine   Alcohol  Malic.acid       Ash       Acl  \
# Wine                  1.000000 -0.328222    0.437776 -0.049643  0.517859
# Alcohol              -0.328222  1.000000    0.094397  0.211545 -0.310235
# Malic.acid            0.437776  0.094397    1.000000  0.164045  0.288500
# Ash                  -0.049643  0.211545    0.164045  1.000000  0.443367
# Acl                   0.517859 -0.310235    0.288500  0.443367  1.000000
# Mg                   -0.209179  0.270798   -0.054575  0.286587 -0.083333
# Phenols              -0.719163  0.289101   -0.335167  0.128980 -0.321113
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077 -0.351370
# Nonflavanoid.phenols  0.489109 -0.155929    0.292977  0.186230  0.361922
# Proanth              -0.499130  0.136698   -0.220746  0.009652 -0.197327
# Color.int             0.265668  0.546364    0.248985  0.258887  0.018732
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667 -0.273955
# ...

# %%
df.cov()
# Out:
#                             Wine     Alcohol  Malic.acid        Ash  \
# Wine                    0.600679   -0.206515    0.379039  -0.010555
# Alcohol                -0.206515    0.659062    0.085611   0.047115
# Malic.acid              0.379039    0.085611    1.248015   0.050277
# Ash                    -0.010555    0.047115    0.050277   0.075265
# Acl                     1.340364   -0.841093    1.076332   0.406208
# Mg                     -2.315495    3.139878   -0.870780   1.122937
# Phenols                -0.348835    0.146887   -0.234338   0.022146
# Flavanoids             -0.656091    0.192033   -0.458630   0.031535
# Nonflavanoid.phenols    0.047177   -0.015754    0.040733   0.006358
# Proanth                -0.221413    0.063518   -0.141147   0.001516
# Color.int               0.477339    1.028283    0.644838   0.164654
# Hue                    -0.109368   -0.013313   -0.143326  -0.004682
# OD                     -0.433737    0.041698   -0.292447   0.000762
# ...

# %%
df.corrwith(df.Mg)
# Out:
# Wine                   -0.209179
# Alcohol                 0.270798
# Malic.acid             -0.054575
# Ash                     0.286587
# Acl                    -0.083333
# Mg                      1.000000
# Phenols                 0.214401
# Flavanoids              0.195784
# Nonflavanoid.phenols   -0.256294
# Proanth                 0.236441
# Color.int               0.199950
# Hue                     0.055398
# OD                      0.066004
# Proline                 0.393351
# dtype: float64

# %%
df["Wine"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
df["Wine"].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Wine, dtype: int64

# %%
f=lambda x:x.max()-x.min()

# %%
df.apply(f)
# Out:
# Wine                       2.00
# Alcohol                    3.80
# Malic.acid                 5.06
# Ash                        1.87
# Acl                       19.40
# Mg                        92.00
# Phenols                    2.90
# Flavanoids                 4.74
# Nonflavanoid.phenols       0.53
# Proanth                    3.17
# Color.int                 11.72
# Hue                        1.23
# OD                         2.73
# Proline                 1402.00
# dtype: float64

# %%
df.apply(f,axis=1)
# Out:
# 0      1064.72
# 1      1049.74
# 2      1184.70
# 3      1479.76
# 4       734.61
#         ...
# 173     739.48
# 174     749.57
# 175     834.57
# 176     839.47
# 177     559.44
# Length: 178, dtype: float64

# %%
def f(x):
    return x**2

# %%
df.apply(f)
# Out:
#      Wine   Alcohol  Malic.acid     Ash     Acl       Mg  Phenols  Flavanoids  \
# 0       1  202.4929      2.9241  5.9049  243.36  16129.0   7.8400      9.3636
# 1       1  174.2400      3.1684  4.5796  125.44  10000.0   7.0225      7.6176
# 2       1  173.1856      5.5696  7.1289  345.96  10201.0   7.8400     10.4976
# 3       1  206.4969      3.8025  6.2500  282.24  12769.0  14.8225     12.1801
# 4       1  175.2976      6.7081  8.2369  441.00  13924.0   7.8400      7.2361
# ..    ...       ...         ...     ...     ...      ...      ...         ...
# 173     9  187.9641     31.9225  6.0025  420.25   9025.0   2.8224      0.3721
# 174     9  179.5600     15.2881  6.1504  529.00  10404.0   3.2400      0.5625
# 175     9  176.0929     18.3184  5.1076  400.00  14400.0   2.5281      0.4761
# 176     9  173.4489      6.7081  5.6169  400.00  14400.0   2.7225      0.4624
# 177     9  199.6569     16.8100  7.5076  600.25   9216.0   4.2025      0.5776
#
# ...

# %%
df.dtypes
# Out:
# Wine                      int64
# Alcohol                 float64
# Malic.acid              float64
# Ash                     float64
# Acl                     float64
# Mg                      float64
# Phenols                 float64
# Flavanoids              float64
# Nonflavanoid.phenols    float64
# Proanth                 float64
# Color.int               float64
# Hue                     float64
# OD                      float64
# Proline                   int64
# dtype: object

# %%
df[["Wine","Alcohol"]].head()
# Out:
#    Wine  Alcohol
# 0     1    14.23
# 1     1    13.20
# 2     1    13.16
# 3     1    14.37
# 4     1    13.24

# %%
df.loc[0,:]
# Out:
# Wine                       1.00
# Alcohol                   14.23
# Malic.acid                 1.71
# Ash                        2.43
# Acl                       15.60
# Mg                       127.00
# Phenols                    2.80
# Flavanoids                 3.06
# Nonflavanoid.phenols       0.28
# Proanth                    2.29
# Color.int                  5.64
# Hue                        1.04
# OD                         3.92
# Proline                 1065.00
# Name: 0, dtype: float64

# %%
df.loc[[0,2,4]]
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127.0      2.8        3.06
# 2     1    13.16        2.36  2.67  18.6  101.0      2.8        3.24
# 4     1    13.24        2.59  2.87  21.0  118.0      2.8        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
df.loc[0:2,]
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185

# %%
df.loc[0:5,"Wine":"Ash"]              #dslicing both rows and columns
# Out:
#    Wine  Alcohol  Malic.acid   Ash
# 0     1    14.23        1.71  2.43
# 1     1    13.20        1.78  2.14
# 2     1    13.16        2.36  2.67
# 3     1    14.37        1.95  2.50
# 4     1    13.24        2.59  2.87
# 5     1    14.20        1.76  2.45

# %%
df.loc[:,"Wine":"Phenols"].head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols
# 0     1    14.23        1.71  2.43  15.6  127.0     2.80
# 1     1    13.20        1.78  2.14  11.2  100.0     2.65
# 2     1    13.16        2.36  2.67  18.6  101.0     2.80
# 3     1    14.37        1.95  2.50  16.8  113.0     3.85
# 4     1    13.24        2.59  2.87  21.0  118.0     2.80

# %%
#You can filter using the loc method

df.loc[df.Wine==1,].head(15)
# Out:
#     Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0      1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1      1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2      1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3      1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4      1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
# 5      1    14.20        1.76  2.45  15.2  112.0     3.27        3.39
# 6      1    14.39        1.87  2.45  14.6   96.0     2.50        2.52
# 7      1    14.06        2.15  2.61  17.6  121.0     2.60        2.51
# 8      1    14.83        1.64  2.17  14.0   97.0     2.80        2.98
# 9      1    13.86        1.35  2.27  16.0   98.0     2.98        3.15
# 10     1    14.10        2.16  2.30  18.0  105.0     2.95        3.32
# 11     1    14.12        1.48  2.32  16.8   95.0     2.20        2.43
# ...

# %%
#you want to filter columns in any row, then you write the column names after the comma. Notice that you have to write the column names in square brackets to select more than one column
df.loc[df.Phenols==2.20,["Proline","OD","Hue"]]
# Out:
#      Proline    OD   Hue
# 11      1280  2.82  1.17
# 81       714  3.14  1.16
# 84       520  3.08  0.79
# 85       450  3.16  1.23
# 89       625  3.21  1.07
# 104      672  3.57  1.04
# 122      365  3.12  0.92
# 152      425  1.33  0.61

# %%
"""The difference between the iloc method and the loc method is that the indexes of rows and columns are entered instead of labels."""
df.iloc[:,0].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Wine, dtype: int64

# %%
df.iloc[:,[0,3]].head()
# Out:
#    Wine   Ash
# 0     1  2.43
# 1     1  2.14
# 2     1  2.67
# 3     1  2.50
# 4     1  2.87

# %%
df.iloc[:,0:3].head()
# Out:
#    Wine  Alcohol  Malic.acid
# 0     1    14.23        1.71
# 1     1    13.20        1.78
# 2     1    13.16        2.36
# 3     1    14.37        1.95
# 4     1    13.24        2.59

# %%
df.iloc[0,0:3]
# Out:
# Wine           1.00
# Alcohol       14.23
# Malic.acid     1.71
# Name: 0, dtype: float64

# %%
df.loc[df.Alcohol>=13]
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
# ..    ...      ...         ...   ...   ...    ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95.0     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102.0     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120.0     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120.0     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96.0     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# ...

# %%
"""You can filter with more than one condition."""

df[(df.Alcohol>=12)|(df.Ash>=3)|(df.Phenols>=3)].head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127.0     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100.0     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101.0     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113.0     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118.0     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
"""You can do practical filtering with the isin method."""

df[df.Wine.isin([2,3])]
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl     Mg  Phenols  Flavanoids  \
# 59      2    12.37        0.94  1.36  10.6   88.0     1.98        0.57
# 60      2    12.33        1.10  2.28  16.0  101.0     2.05        1.09
# 61      2    12.64        1.36  2.02  16.8  100.0     2.02        1.41
# 62      2    13.67        1.25  1.92  18.0   94.0     2.10        1.79
# 63      2    12.37        1.13  2.16  19.0   87.0     3.50        3.10
# ..    ...      ...         ...   ...   ...    ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95.0     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102.0     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120.0     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120.0     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96.0     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# ...
